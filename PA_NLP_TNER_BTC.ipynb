# %% [markdown]
# # T-NER: Model Training Example
# An example of using [T-NER](https://github.com/asahi417/tner) to finetune & evaluate language model on NER.
#
# ***Table of Contents***
# - [Finetuning & Evaluation on single dataset](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=23QyG8ypSILQ&line=2&uniqifier=1)
# - [Finetuning & Evaluation on multiple datasets](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=L7R5qjXRdPWb&line=2&uniqifier=1)
# - [Finetuning & Evaluation on a custom dataset](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=nB6i22foeCjV&line=1&uniqifier=1)

# %% [markdown]
# ### Setup

# %%
# main package
# %pip install tner -U
# %pip list | grep tner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tner
#   Downloading tner-0.1.9.tar.gz (2.2 MB)
#      |████████████████████████████████| 2.2 MB 5.2 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from tner) (1.12.1+cu113)
# Collecting allennlp>=2.0.0
#   Downloading allennlp-2.10.0-py3-none-any.whl (729 kB)
#      |████████████████████████████████| 729 kB 61.8 MB/s
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 48.4 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 65.0 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.2 MB/s
# Collecting datasets
#   Downloading datasets-2.5.2-py3-none-any.whl (432 kB)
#      |████████████████████████████████| 432 kB 4.5 MB/s
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.7.3)
# Collecting h5py>=3.6.0
#   Downloading h5py-3.7.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
#      |████████████████████████████████| 4.1 MB 39.9 MB/s
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.21.6)
# Collecting pytest>=6.2.5
#   Downloading pytest-7.1.3-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 71.3 MB/s
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 65.7 MB/s
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (0.4.2)
# Collecting rich==12.1
#   Downloading rich-12.1.0-py3-none-any.whl (229 kB)
#      |████████████████████████████████| 229 kB 62.6 MB/s
# Collecting requests>=2.28
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 65.9 MB/s
# Collecting jsonnet>=0.10.0
#   Downloading jsonnet-0.18.0.tar.gz (592 kB)
#      |████████████████████████████████| 592 kB 60.5 MB/s
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.0.2)
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (8.14.0)
# Collecting lmdb>=1.2.1
#   Downloading lmdb-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (298 kB)
#      |████████████████████████████████| 298 kB 68.1 MB/s
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (4.64.1)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      |████████████████████████████████| 248 kB 64.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 64.8 MB/s
# Collecting protobuf==3.20.0
#   Downloading protobuf-3.20.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 68.8 MB/s
# Collecting torchvision<0.13.0,>=0.8.1
#   Downloading torchvision-0.12.0-cp37-cp37m-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 100.4 MB/s
# Collecting filelock<3.8,>=3.3
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting torch
#   Downloading torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 11 kB/s
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 49.7 MB/s
# Collecting spacy<3.4,>=2.1.0
#   Downloading spacy-3.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 53.1 MB/s
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (0.3.5.1)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (3.7)
# Collecting traitlets>5.1.1
#   Downloading traitlets-5.4.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 63.1 MB/s
# Collecting transformers
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 48.4 MB/s
# Collecting cached-path<1.2.0,>=1.1.3
#   Downloading cached_path-1.1.6-py3-none-any.whl (26 kB)
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp>=2.0.0->tner) (4.1.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.9 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich==12.1->allennlp>=2.0.0->tner) (2.6.1)
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.24.89-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 70.8 MB/s
# Collecting google-cloud-storage<3.0,>=1.32.0
#   Downloading google_cloud_storage-2.5.0-py2.py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 73.5 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.9 MB/s
# Collecting botocore<1.28.0,>=1.27.89
#   Downloading botocore-1.27.89-py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 53.5 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 58.9 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.89->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.8.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.35.0)
# Collecting google-resumable-media>=2.3.2
#   Downloading google_resumable_media-2.4.0-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.8 MB/s
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.31.6)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.3.2-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.56.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (21.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (57.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2022.4)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (4.2.4)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (5.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (0.4.8)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp>=2.0.0->tner) (1.11.0)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp>=2.0.0->tner) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp>=2.0.0->tner) (22.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (3.8.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.1->allennlp>=2.0.0->tner) (3.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.3.0)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 60.6 MB/s
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.4.4)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.7.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.6)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 28.6 MB/s
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.0.10)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (1.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (1.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (5.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.13.0,>=0.8.1->allennlp>=2.0.0->tner) (7.1.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 817 kB/s
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.3 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp>=2.0.0->tner) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp>=2.0.0->tner) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 70.2 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.2 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (3.8.3)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 76.3 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (2022.8.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (1.3.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 73.9 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.1)
# WARNING: The candidate selected for download or install is a yanked version: 'rich' candidate (version 12.1.0 at https://files.pythonhosted.org/packages/bc/be/1ace556afa0cf17599c2a631b04b280ae7502a9cf942c47fd66ca9ab5134/rich-12.1.0-py3-none-any.whl#sha256=b60ff99f4ff7e3d1d37444dee2b22fdd941c622dbc37841823ec1ce7f058b263 (from https://pypi.org/simple/rich/) (requires-python:>=3.6.2,<4.0.0))
# Reason for being yanked: Broken dependencies. Please upgrade to 12.2.0 or later
# Building wheels for collected packages: tner, fairscale, termcolor, jsonnet, pathtools, sacremoses, seqeval
#   Building wheel for tner (setup.py) ... done
#   Created wheel for tner: filename=tner-0.1.9-py3-none-any.whl size=39795 sha256=31ac6a55068bb6ac19b4a7492a675ae08164f173671db88e6b976d1b0afeb86c
#   Stored in directory: /root/.cache/pip/wheels/96/2a/ba/b333711e94584598952cf475456f8ba4bcbf30340ecac73b53
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307252 sha256=8086e6de5427d1a2e1114c9859b9a5094b7bed8143e7b506a1edc1cd8d874633
#   Stored in directory: /root/.cache/pip/wheels/4e/4f/0b/94c29ea06dfad93260cb0377855f87b7b863312317a7f69fe7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=8e4613d7063fc252fd15b2368e43524d6bc6f40685df461627ab1ff0e70548a3
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.18.0-cp37-cp37m-linux_x86_64.whl size=3994685 sha256=349f0ff309bea2324798a335893c9c4efd7d4bf30159c8ca0c8cf0fd9cda13b6
#   Stored in directory: /root/.cache/pip/wheels/a9/63/f9/a653f9c21575e6ff271ee6a49939aa002005174cea6c35919d
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=c1431fe0da2bd817819bddf1ed9894d3193bce30aef3429fe20dac10d8703d17
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=507dda078b8eb163d720c9377f8c617393c6b23d83af6fd9daf5e0d0781bf02c
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=251338872b6d9a4831997e7a90056cecf03c0d701765d4a46467f656704a2271
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built tner fairscale termcolor jsonnet pathtools sacremoses seqeval
# Installing collected packages: urllib3, protobuf, requests, jmespath, smmap, google-crc32c, botocore, s3transfer, pydantic, google-resumable-media, google-cloud-core, gitdb, filelock, commonmark, torch, tokenizers, thinc, shortuuid, setproctitle, sentry-sdk, rich, pluggy, pathtools, iniconfig, huggingface-hub, google-cloud-storage, GitPython, docker-pycreds, boto3, xxhash, wandb, transformers, traitlets, torchvision, termcolor, tensorboardX, spacy, sentencepiece, sacremoses, responses, pytest, multiprocess, lmdb, jsonnet, h5py, fairscale, cached-path, base58, seqeval, datasets, allennlp, tner
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.9.2
#     Uninstalling pydantic-1.9.2:
#       Successfully uninstalled pydantic-1.9.2
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.8.0
#     Uninstalling filelock-3.8.0:
#       Successfully uninstalled filelock-3.8.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.2
#     Uninstalling thinc-8.1.2:
#       Successfully uninstalled thinc-8.1.2
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.0.1
#     Uninstalling termcolor-2.0.1:
#       Successfully uninstalled termcolor-2.0.1
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.1
#     Uninstalling spacy-3.4.1:
#       Successfully uninstalled spacy-3.4.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: lmdb
#     Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# tensorflow 2.8.2+zzzcolab20220929150707 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-translate 1.5.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.3.2 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1, but you have google-resumable-media 2.4.0 which is incompatible.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.1 which is incompatible.
# Successfully installed GitPython-3.1.29 allennlp-2.10.0 base58-2.1.1 boto3-1.24.89 botocore-1.27.89 cached-path-1.1.6 commonmark-0.9.1 datasets-2.5.2 docker-pycreds-0.4.0 fairscale-0.4.6 filelock-3.7.1 gitdb-4.0.9 google-cloud-core-2.3.2 google-cloud-storage-2.5.0 google-crc32c-1.5.0 google-resumable-media-2.4.0 h5py-3.7.0 huggingface-hub-0.10.1 iniconfig-1.1.1 jmespath-1.0.1 jsonnet-0.18.0 lmdb-1.3.0 multiprocess-0.70.13 pathtools-0.1.2 pluggy-1.0.0 protobuf-3.20.0 pydantic-1.8.2 pytest-7.1.3 requests-2.28.1 responses-0.18.0 rich-12.1.0 s3transfer-0.6.0 sacremoses-0.0.53 sentencepiece-0.1.97 sentry-sdk-1.9.10 seqeval-1.2.2 setproctitle-1.3.2 shortuuid-1.0.9 smmap-5.0.0 spacy-3.3.1 tensorboardX-2.5.1 termcolor-1.1.0 thinc-8.0.17 tner-0.1.9 tokenizers-0.12.1 torch-1.11.0 torchvision-0.12.0 traitlets-5.4.0 transformers-4.20.1 urllib3-1.26.12 wandb-0.12.21 xxhash-3.0.0
# tner                          0.1.9

# %%
import logging
from tner import GridSearcher, TransformersNER

logging.basicConfig(format='%(asctime)s %(levelname)-8s %(message)s', level=logging.INFO, datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Finetuning
# Let's finetune `albert-base-v1` on `wnut2017`!

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_bionlp2004',
   dataset="tner/btc",  # either of `dataset` (huggingface dataset) or `local_dataset` (custom dataset) should be given
   model="roberta-large",  # language model to fine-tune
   epoch=10,  # the total epoch (`L` in the figure)
   epoch_partial=5,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=32,
   gradient_accumulation_steps=[2],
   crf=[True],
   lr=[1e-3, 1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()
# Out:
# INFO:root:INITIALIZE GRID SEARCHER: 4 configs to try
# INFO:root:## 1st RUN: Configuration 0/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/btc
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# Downloading builder script:   0%|          | 0.00/3.81k [00:00<?, ?B/s]
# Downloading and preparing dataset btc/btc to /root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/464k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/196k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--btc.ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37.btc:generating examples from = /root/.cache/huggingface/datasets/downloads/f2cfc12e556282a47bd84b744336cebe8b91991572a47d159862eadbd863faee
# Generating validation split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--btc.ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37.btc:generating examples from = /root/.cache/huggingface/datasets/downloads/95d25fc1504243df57f0989f29e46953fc62187453a4f3bdcfe6ba715687c0a6
# Generating test split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--btc.ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37.btc:generating examples from = /root/.cache/huggingface/datasets/downloads/f2be6f07f5dbe588f52886a5f118fb1abebc00759ef7be685832f8347f729e50
# Dataset btc downloaded and prepared to /root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 6338
# INFO:root:preprocessed feature is saved at ./ckpt_bert_bionlp2004/model_jwdmql/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 610.94, lr: 0.0002525252525252525
# INFO:root:	 * global step 100: loss: 490.2, lr: 0.000505050505050505
# INFO:root:	 * global step 150: loss: 521.49, lr: 0.0007575757575757576
# INFO:root:[epoch 0/10] average loss: 536.3, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 582.65, lr: 0.0009719416386083053
# INFO:root:	 * global step 100: loss: 570.31, lr: 0.0009438832772166106
# INFO:root:	 * global step 150: loss: 569.6, lr: 0.0009158249158249159
# INFO:root:[epoch 1/10] average loss: 567.82, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 570.67, lr: 0.0008608305274971942
# INFO:root:	 * global step 100: loss: 568.54, lr: 0.0008327721661054994
# INFO:root:	 * global step 150: loss: 566.01, lr: 0.0008047138047138047
# INFO:root:[epoch 2/10] average loss: 567.44, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 576.06, lr: 0.0007497194163860831
# INFO:root:	 * global step 100: loss: 570.86, lr: 0.0007216610549943883
# INFO:root:	 * global step 150: loss: 563.19, lr: 0.0006936026936026936
# INFO:root:[epoch 3/10] average loss: 564.72, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 583.98, lr: 0.0006386083052749719
# INFO:root:	 * global step 100: loss: 572.2, lr: 0.0006105499438832773
# INFO:root:	 * global step 150: loss: 563.71, lr: 0.0005824915824915825
# INFO:root:[epoch 4/10] average loss: 562.16, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_jwdmql/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_bionlp2004/model_jwdmql
# INFO:root:## 1st RUN: Configuration 1/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/btc
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 6338
# INFO:root:preprocessed feature is saved at ./ckpt_bert_bionlp2004/model_udaxih/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 599.86, lr: 0.0002525252525252525
# INFO:root:	 * global step 100: loss: 467.2, lr: 0.000505050505050505
# INFO:root:	 * global step 150: loss: 516.04, lr: 0.0007575757575757576
# INFO:root:[epoch 0/10] average loss: 535.06, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 564.01, lr: 0.0009719416386083053
# INFO:root:	 * global step 100: loss: 550.48, lr: 0.0009438832772166106
# INFO:root:	 * global step 150: loss: 551.07, lr: 0.0009158249158249159
# INFO:root:[epoch 1/10] average loss: 549.03, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 548.63, lr: 0.0008608305274971942
# INFO:root:	 * global step 100: loss: 545.83, lr: 0.0008327721661054994
# INFO:root:	 * global step 150: loss: 544.83, lr: 0.0008047138047138047
# INFO:root:[epoch 2/10] average loss: 548.79, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 553.29, lr: 0.0007497194163860831
# INFO:root:	 * global step 100: loss: 547.64, lr: 0.0007216610549943883
# INFO:root:	 * global step 150: loss: 540.26, lr: 0.0006936026936026936
# INFO:root:[epoch 3/10] average loss: 541.14, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 565.57, lr: 0.0006386083052749719
# INFO:root:	 * global step 100: loss: 552.73, lr: 0.0006105499438832773
# INFO:root:	 * global step 150: loss: 544.46, lr: 0.0005824915824915825
# INFO:root:[epoch 4/10] average loss: 541.96, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_bionlp2004/model_udaxih
# INFO:root:## 1st RUN: Configuration 2/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/btc
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 6338
# INFO:root:preprocessed feature is saved at ./ckpt_bert_bionlp2004/model_hexdvx/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 948.1, lr: 2.5252525252525256e-05
# INFO:root:	 * global step 100: loss: 620.18, lr: 5.050505050505051e-05
# INFO:root:	 * global step 150: loss: 467.57, lr: 7.575757575757576e-05
# INFO:root:[epoch 0/10] average loss: 389.61, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 115.03, lr: 9.719416386083054e-05
# INFO:root:	 * global step 100: loss: 112.95, lr: 9.438832772166107e-05
# INFO:root:	 * global step 150: loss: 110.58, lr: 9.15824915824916e-05
# INFO:root:[epoch 1/10] average loss: 112.31, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 85.17, lr: 8.608305274971942e-05
# INFO:root:	 * global step 100: loss: 84.28, lr: 8.327721661054994e-05
# INFO:root:	 * global step 150: loss: 83.09, lr: 8.047138047138047e-05
# INFO:root:[epoch 2/10] average loss: 85.62, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 58.94, lr: 7.497194163860831e-05
# INFO:root:	 * global step 100: loss: 57.37, lr: 7.216610549943884e-05
# INFO:root:	 * global step 150: loss: 56.27, lr: 6.936026936026936e-05
# INFO:root:[epoch 3/10] average loss: 56.01, lr: 6.666666666666667e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 38.0, lr: 6.38608305274972e-05
# INFO:root:	 * global step 100: loss: 39.01, lr: 6.105499438832773e-05
# INFO:root:	 * global step 150: loss: 38.01, lr: 5.8249158249158255e-05
# INFO:root:[epoch 4/10] average loss: 38.24, lr: 5.555555555555556e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_bionlp2004/model_hexdvx
# INFO:root:## 1st RUN: Configuration 3/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/btc
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 6338
# INFO:root:preprocessed feature is saved at ./ckpt_bert_bionlp2004/model_rcsnba/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 927.99, lr: 2.5252525252525256e-05
# INFO:root:	 * global step 100: loss: 588.19, lr: 5.050505050505051e-05
# INFO:root:	 * global step 150: loss: 451.1, lr: 7.575757575757576e-05
# INFO:root:[epoch 0/10] average loss: 384.33, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 147.04, lr: 9.719416386083054e-05
# INFO:root:	 * global step 100: loss: 144.69, lr: 9.438832772166107e-05
# INFO:root:	 * global step 150: loss: 145.41, lr: 9.15824915824916e-05
# INFO:root:[epoch 1/10] average loss: 145.21, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 120.61, lr: 8.608305274971942e-05
# INFO:root:	 * global step 100: loss: 122.86, lr: 8.327721661054994e-05
# INFO:root:	 * global step 150: loss: 115.01, lr: 8.047138047138047e-05
# INFO:root:[epoch 2/10] average loss: 115.62, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 101.01, lr: 7.497194163860831e-05
# INFO:root:	 * global step 100: loss: 101.28, lr: 7.216610549943884e-05
# INFO:root:	 * global step 150: loss: 103.82, lr: 6.936026936026936e-05
# INFO:root:[epoch 3/10] average loss: 102.17, lr: 6.666666666666667e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 84.86, lr: 6.38608305274972e-05
# INFO:root:	 * global step 100: loss: 84.95, lr: 6.105499438832773e-05
# INFO:root:	 * global step 150: loss: 82.43, lr: 5.8249158249158255e-05
# INFO:root:[epoch 4/10] average loss: 82.38, lr: 5.555555555555556e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_rcsnba/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_bionlp2004/model_rcsnba
# INFO:root:## 1st RUN (EVAL): Configuration 0/4 ##
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_jwdmql/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:encode all the data: 1001
# INFO:root:preprocessed feature is saved at ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.07it/s]
# INFO:root:downloading `unified_label2id.json` from https://raw.githubusercontent.com/asahi417/tner/master/unified_label2id.json
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.00      0.00      0.00       156
# organization       0.00      0.00      0.00       380
#       person       0.00      0.00      0.00      1194
#
#    micro avg       0.00      0.00      0.00      1730
#    macro avg       0.00      0.00      0.00      1730
# weighted avg       0.00      0.00      0.00      1730
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:root:## 1st RUN (EVAL): Configuration 1/4 ##
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_udaxih/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.04it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.00      0.00      0.00       156
# organization       0.00      0.00      0.00       380
#       person       0.00      0.00      0.00      1194
#
#    micro avg       0.00      0.00      0.00      1730
#    macro avg       0.00      0.00      0.00      1730
# weighted avg       0.00      0.00      0.00      1730
#
# INFO:root:## 1st RUN (EVAL): Configuration 2/4 ##
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.06it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.68      0.65      0.67       156
# organization       0.68      0.58      0.63       380
#       person       0.89      0.90      0.90      1194
#
#    micro avg       0.83      0.81      0.82      1730
#    macro avg       0.75      0.71      0.73      1730
# weighted avg       0.83      0.81      0.82      1730
#
# INFO:root:## 1st RUN (EVAL): Configuration 3/4 ##
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_rcsnba/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.08it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.80      0.55      0.65       156
# organization       0.66      0.39      0.49       380
#       person       0.87      0.83      0.85      1194
#
#    micro avg       0.83      0.71      0.76      1730
#    macro avg       0.78      0.59      0.66      1730
# weighted avg       0.82      0.71      0.75      1730
#
# INFO:root:1st RUN RESULTS
# INFO:root:	 * rank: 0 | metric: 0.82 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5 |
# INFO:root:	 * rank: 1 | metric: 0.764 | model: ./ckpt_bert_bionlp2004/model_rcsnba/epoch_5 |
# INFO:root:	 * rank: 2 | metric: 0.0 | model: ./ckpt_bert_bionlp2004/model_jwdmql/epoch_5 |
# INFO:root:	 * rank: 3 | metric: 0.0 | model: ./ckpt_bert_bionlp2004/model_udaxih/epoch_5 |
# INFO:root:## 2nd RUN: Configuration 0/1: 0.8197298884321785
# INFO:root:load checkpoint from ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:root:config is overwritten by ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/btc
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:dataset preprocessing
# INFO:root:load optimizer from ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:optimizer is loading on cuda
# INFO:root:load scheduler from ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/model_hexdvx/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 31.52, lr: 5.274971941638609e-05
# INFO:root:	 * global step 100: loss: 32.02, lr: 4.994388327721661e-05
# INFO:root:	 * global step 150: loss: 30.15, lr: 4.713804713804714e-05
# INFO:root:[epoch 5/10] average loss: 28.9, lr: 4.4444444444444447e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_6
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_6
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_6
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.6.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 17.74, lr: 4.163860830527497e-05
# INFO:root:	 * global step 100: loss: 15.93, lr: 3.88327721661055e-05
# INFO:root:	 * global step 150: loss: 16.25, lr: 3.602693602693603e-05
# INFO:root:[epoch 6/10] average loss: 17.35, lr: 3.3333333333333335e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_7
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_7
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_7
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.7.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 14.39, lr: 3.0527497194163865e-05
# INFO:root:	 * global step 100: loss: 12.52, lr: 2.7721661054994393e-05
# INFO:root:	 * global step 150: loss: 11.71, lr: 2.4915824915824916e-05
# INFO:root:[epoch 7/10] average loss: 11.66, lr: 2.2222222222222223e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_8
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_8
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_8
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.8.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 7.16, lr: 1.941638608305275e-05
# INFO:root:	 * global step 100: loss: 7.29, lr: 1.6610549943883278e-05
# INFO:root:	 * global step 150: loss: 6.92, lr: 1.3804713804713806e-05
# INFO:root:[epoch 8/10] average loss: 7.09, lr: 1.1111111111111112e-05
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_9
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_9
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_9
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.9.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 5.07, lr: 8.305274971941639e-06
# INFO:root:	 * global step 100: loss: 4.46, lr: 5.499438832772167e-06
# INFO:root:	 * global step 150: loss: 4.75, lr: 2.6936026936026934e-06
# INFO:root:[epoch 9/10] average loss: 5.07, lr: 0.0
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.10.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:saving model weight at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:saving tokenizer at ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10
# INFO:root:optimizer saving at ./ckpt_bert_bionlp2004/model_hexdvx/optimizers/optimizer.10.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_bionlp2004/model_hexdvx
# INFO:root:## 2nd RUN (EVAL): Configuration 0/1 ##
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_1`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:31<00:00,  1.97it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.70      0.59      0.64       156
# organization       0.55      0.56      0.55       380
#       person       0.87      0.78      0.83      1194
#
#    micro avg       0.78      0.72      0.75      1730
#    macro avg       0.71      0.64      0.67      1730
# weighted avg       0.79      0.72      0.75      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_10`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.07it/s]
# ...
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.69      0.67      0.68       156
# organization       0.59      0.59      0.59       380
#       person       0.89      0.83      0.86      1194
#
#    micro avg       0.80      0.76      0.78      1730
#    macro avg       0.72      0.69      0.71      1730
# weighted avg       0.80      0.76      0.78      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_4`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.05it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.68      0.65      0.66       156
# organization       0.60      0.59      0.59       380
#       person       0.90      0.84      0.87      1194
#
#    micro avg       0.81      0.76      0.79      1730
#    macro avg       0.73      0.69      0.71      1730
# weighted avg       0.82      0.76      0.79      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_6`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:31<00:00,  2.01it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.62      0.64      0.63       156
# organization       0.64      0.53      0.58       380
#       person       0.89      0.88      0.88      1194
#
#    micro avg       0.82      0.78      0.80      1730
#    macro avg       0.72      0.68      0.70      1730
# weighted avg       0.81      0.78      0.79      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_7`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.06it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.77      0.54      0.63       156
# organization       0.64      0.55      0.59       380
#       person       0.87      0.89      0.88      1194
#
#    micro avg       0.82      0.79      0.80      1730
#    macro avg       0.76      0.66      0.70      1730
# weighted avg       0.81      0.79      0.80      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_8`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.07it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.73      0.62      0.67       156
# organization       0.61      0.57      0.59       380
#       person       0.90      0.86      0.88      1194
#
#    micro avg       0.83      0.78      0.80      1730
#    macro avg       0.75      0.68      0.71      1730
# weighted avg       0.82      0.78      0.80      1730
#
# INFO:root:initialize language model with `./ckpt_bert_bionlp2004/model_hexdvx/epoch_9`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_bionlp2004/encoded/roberta-large.128.dev.True.validation.pkl
# 100%|██████████| 63/63 [00:30<00:00,  2.06it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.73      0.62      0.67       156
# organization       0.65      0.57      0.60       380
#       person       0.90      0.89      0.89      1194
#
#    micro avg       0.83      0.79      0.81      1730
#    macro avg       0.76      0.69      0.72      1730
# weighted avg       0.83      0.79      0.81      1730
#
# INFO:root:2nd RUN RESULTS:
# [('./ckpt_bert_bionlp2004/model_hexdvx/epoch_5', 0.8197298884321785), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_9', 0.812666469369636), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_10', 0.8047832585949177), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_2', 0.8036937742031576), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_7', 0.8027170702894271), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_8', 0.8013106940720881), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_6', 0.7969258054980786), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_4', 0.7879690291840381), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_3', 0.7808056872037915), ('./ckpt_bert_bionlp2004/model_hexdvx/epoch_1', 0.7477368738684369)]
# INFO:root:	 * rank: 0 | metric: 0.82 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_5 |
# INFO:root:	 * rank: 1 | metric: 0.813 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_9 |
# INFO:root:	 * rank: 2 | metric: 0.805 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_10 |
# INFO:root:	 * rank: 3 | metric: 0.804 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_2 |
# INFO:root:	 * rank: 4 | metric: 0.803 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_7 |
# INFO:root:	 * rank: 5 | metric: 0.801 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_8 |
# INFO:root:	 * rank: 6 | metric: 0.797 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_6 |
# INFO:root:	 * rank: 7 | metric: 0.788 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_4 |
# INFO:root:	 * rank: 8 | metric: 0.781 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_3 |
# INFO:root:	 * rank: 9 | metric: 0.748 | model: ./ckpt_bert_bionlp2004/model_hexdvx/epoch_1 |

# %% [markdown]
# ### Evaluation
# Now the best model is stored at `ckpt_bert_wnut2017/best_model`, so let's load the model run evaluation on the test split.

# %% [markdown]
# First, we load the model and check the prediction.

# %%
model = TransformersNER("ckpt_bert_bionlp2004/best_model")
model.predict(["Jacob Collier is a Grammy awarded English artist from London"])
# Out:
# INFO:root:initialize language model with `ckpt_bert_bionlp2004/best_model`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:encode all the data: 1
# 100%|██████████| 1/1 [00:00<00:00,  6.94it/s]
# {'prediction': [['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC']],
#  'probability': [[0.9953048229217529,
#    0.9996180534362793,
#    0.9994888305664062,
#    0.999830961227417,
#    0.9918205738067627,
#    0.9998334646224976,
#    0.9804861545562744,
#    0.9998149275779724,
#    0.9991379976272583,
#    0.9992963075637817]],
#  'input': [['Jacob',
#    'Collier',
#    'is',
#    'a',
#    'Grammy',
#    'awarded',
#    'English',
#    'artist',
#    'from',
#    'London']],
#  'entity_prediction': [[{'type': 'PER',
#     'entity': ['Jacob', 'Collier'],
#     'position': [0, 1],
#     'probability': [0.9953048229217529, 0.9996180534362793]},
#    {'type': 'LOC',
#     'entity': ['London'],
#     'position': [9],
#     'probability': [0.9992963075637817]}]]}

# %% [markdown]
# Then, the model instance has `evaluate` function where one can run evaluatino on the dataset easily.

# %%
metric = model.evaluate('tner/btc', dataset_split='test', batch_size=16)
# Out:
# WARNING:datasets.builder:Found cached dataset btc (/root/.cache/huggingface/datasets/tner___btc/btc/1.0.0/ba7dfb92f97e0ae98ff48df9a35a6821285a4b3d3ed284bb177e17f7562c3c37)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-LOC': 0, 'B-ORG': 1, 'B-PER': 2, 'I-LOC': 3, 'I-ORG': 4, 'I-PER': 5, 'O': 6} but not changed as is only one dataset
# INFO:root:encode all the data: 2000
# 100%|██████████| 125/125 [01:02<00:00,  2.00it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#     location       0.74      0.74      0.74       636
# organization       0.72      0.64      0.68      1090
#       person       0.91      0.91      0.91      2650
#
#    micro avg       0.84      0.82      0.83      4376
#    macro avg       0.79      0.76      0.77      4376
# weighted avg       0.84      0.82      0.83      4376

# %%
metric
# Out:
# {'micro/f1': 0.8289794496691048,
#  'micro/f1_ci': {},
#  'micro/recall': 0.8158135283363802,
#  'micro/precision': 0.8425772952560774,
#  'macro/f1': 0.7746975422092938,
#  'macro/f1_ci': {},
#  'macro/recall': 0.7608068393822244,
#  'macro/precision': 0.7904438081295443,
#  'per_entity_metric': {'location': {'f1': 0.736842105263158,
#    'f1_ci': {},
#    'precision': 0.7362637362637363,
#    'recall': 0.7374213836477987},
#   'organization': {'f1': 0.6774036115178135,
#    'f1_ci': {},
#    'precision': 0.7236704900938478,
#    'recall': 0.636697247706422},
#   'person': {'f1': 0.9098469098469099,
#    'f1_ci': {},
#    'precision': 0.9113971980310488,
#    'recall': 0.9083018867924528}}}

# %% [markdown]
# ## Finetuning on multiple datasets
# To finetune on multiple datasets, we need to give a list to the variable `dataset`.

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_multiple_dataset',
   dataset=["tner/wnut2017", "tner/fin"],  # either of `dataset` (huggingface dataset) or `local_dataset` (custom dataset) should be given
   model="distilbert-base-cased",  # language model to fine-tune
   epoch=10,  # the total epoch (`L` in the figure)
   epoch_partial=5,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=32,
   gradient_accumulation_steps=[2],
   crf=[True],
   lr=[1e-3, 1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()

# %%
model = TransformersNER("ckpt_bert_multiple_dataset/best_model")
metric_wnut = model.evaluate('tner/wnut2017', dataset_split='test', batch_size=16)
metric_fin = model.evaluate('tner/fin', dataset_split='test', batch_size=16)

# %%
metric_wnut

# %%
metric_fin

# %% [markdown]
# ## Finetuning on a custom dataset
# Finetuning on a [custom dataset](https://github.com/asahi417/tner/tree/master/examples/custom_dataset_sample).

# %%
# !mkdir ./custom_data
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/train.txt -O custom_data/train.txt
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/valid.txt -O custom_data/valid.txt
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/test.txt -O custom_data/test.txt

# %%
# !head -n 5 custom_data/train.txt

# %%
local_dataset = {"train": "custom_data/train.txt", "validation": "custom_data/valid.txt", "test": "custom_data/test.txt"}

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_custom_dataset',
   local_dataset=local_dataset,
   model="distilbert-base-cased",  # language model to fine-tune
   epoch=2,  # the total epoch (`L` in the figure)
   epoch_partial=1,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=4,
   gradient_accumulation_steps=[1],
   crf=[True],
   lr=[1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()

# %%
model = TransformersNER("ckpt_bert_custom_dataset/best_model")
metric = model.evaluate(local_dataset=local_dataset, dataset_split='test', batch_size=16)

# %%
metric
