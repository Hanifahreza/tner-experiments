# %% [markdown]
# # T-NER: Model Training Example
# An example of using [T-NER](https://github.com/asahi417/tner) to finetune & evaluate language model on NER.
#
# ***Table of Contents***
# - [Finetuning & Evaluation on single dataset](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=23QyG8ypSILQ&line=2&uniqifier=1)
# - [Finetuning & Evaluation on multiple datasets](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=L7R5qjXRdPWb&line=2&uniqifier=1)
# - [Finetuning & Evaluation on a custom dataset](https://colab.research.google.com/drive/1AlcTbEsp8W11yflT7SyT0L4C4HG6MXYr#scrollTo=nB6i22foeCjV&line=1&uniqifier=1)

# %% [markdown]
# ### Setup

# %%
# main package
# %pip install tner -U
# %pip list | grep tner
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tner
#   Using cached tner-0.2.0.tar.gz (2.2 MB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from tner) (1.12.1+cu113)
# Collecting allennlp>=2.0.0
#   Using cached allennlp-2.10.1-py3-none-any.whl (730 kB)
# Collecting transformers
#   Using cached transformers-4.24.0-py3-none-any.whl (5.5 MB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting seqeval
#   Using cached seqeval-1.2.2.tar.gz (43 kB)
# Collecting datasets
#   Using cached datasets-2.7.0-py3-none-any.whl (451 kB)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (0.4.2)
# Collecting lmdb>=1.2.1
#   Using cached lmdb-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (298 kB)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (3.19.6)
# Requirement already satisfied: scikit-learn>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.0.2)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (4.64.1)
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 5.1 MB/s
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 35.5 MB/s
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (9.0.0)
# Collecting traitlets>5.1.1
#   Using cached traitlets-5.5.0-py3-none-any.whl (107 kB)
# Collecting h5py>=3.6.0
#   Using cached h5py-3.7.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.1 MB)
# Collecting spacy<3.4,>=2.1.0
#   Using cached spacy-3.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.7.3)
# Requirement already satisfied: torchvision<0.14.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (0.13.1+cu113)
# Collecting filelock<3.8,>=3.3
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 60.7 MB/s
# Collecting cached-path<1.2.0,>=1.1.3
#   Using cached cached_path-1.1.6-py3-none-any.whl (26 kB)
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: numpy>=1.21.4 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (1.21.6)
# Collecting transformers
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 54.2 MB/s
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (0.3.6)
# Collecting fairscale==0.4.6
#   Using cached fairscale-0.4.6.tar.gz (248 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting jsonnet>=0.10.0
#   Using cached jsonnet-0.19.1.tar.gz (593 kB)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from allennlp>=2.0.0->tner) (3.7)
# Collecting requests>=2.28
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting pytest>=6.2.5
#   Downloading pytest-7.2.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 59.1 MB/s
# Collecting sacremoses
#   Using cached sacremoses-0.0.53.tar.gz (880 kB)
# Collecting rich<13.0,>=12.1
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      |████████████████████████████████| 237 kB 50.0 MB/s
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.5.0)
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.26.11-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 63.2 MB/s
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 69.9 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.7 MB/s
# Collecting botocore<1.30.0,>=1.29.11
#   Downloading botocore-1.29.11-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 43.1 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 69.6 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.30.0,>=1.29.11->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.8.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.4.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.14.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.3.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.8.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.56.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.7/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (1.5.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (4.13.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (4.1.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.5->allennlp>=2.0.0->tner) (2022.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (0.4.8)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp>=2.0.0->tner) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest>=6.2.5->allennlp>=2.0.0->tner) (22.1.0)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.0.16->allennlp>=2.0.0->tner) (3.10.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.28->allennlp>=2.0.0->tner) (2.10)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 7.6 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp>=2.0.0->tner) (2.6.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.1->allennlp>=2.0.0->tner) (3.1.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.6.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.4.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (1.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (1.0.9)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 59.6 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (3.0.8)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 50.1 MB/s
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (0.7.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (5.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision<0.14.0,>=0.8.1->allennlp>=2.0.0->tner) (7.1.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 48.8 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 73.5 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp>=2.0.0->tner) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb<0.13.0,>=0.10.0->allennlp>=2.0.0->tner) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 64.2 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (2022.10.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 68.5 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (1.3.5)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 68.3 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets->tner) (3.8.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets->tner) (0.13.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp>=2.0.0->tner) (2.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets->tner) (2022.6)
# Building wheels for collected packages: tner, fairscale, termcolor, jsonnet, pathtools, sacremoses, seqeval
#   Building wheel for tner (setup.py) ... done
#   Created wheel for tner: filename=tner-0.2.0-py3-none-any.whl size=39815 sha256=cc24af71df0fdf46afe0287db0393aabcf8a317d900805f65780000b4df402d3
#   Stored in directory: /root/.cache/pip/wheels/6b/54/c4/ae6a299f9f8d84f8eccb2ce5d2043398b3e8e1ccacd0602c72
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307252 sha256=0319d8a69f1970f00cc091b6be5b1041a34210cd6e12efdbbb0e634e397efcf3
#   Stored in directory: /root/.cache/pip/wheels/4e/4f/0b/94c29ea06dfad93260cb0377855f87b7b863312317a7f69fe7
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4849 sha256=16181881e3de26d4f0a31fb71d66b24a77a4df76797f28e0372980fb40bd4b7e
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.19.1-cp37-cp37m-linux_x86_64.whl size=3997170 sha256=84d4643bb7ed370471d094b84301b154ae83f9ec729654ed4f4a6761d302466e
#   Stored in directory: /root/.cache/pip/wheels/03/6b/48/a168ed5f8d01c50268605eff341c29126286763607bf707e3b
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=7d177c26c004f44fee74dd7ff6ac9842e970e285d8ddecf501cce4ca739eb2c9
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=3eef4bebf69598fb6a728fb8321514a071d970f6b433cf4baafcfa38f151dc84
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16182 sha256=3513522cdb1241aa2e7450698847b384a04c656acb0ab7110343fdb07b801cdf
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built tner fairscale termcolor jsonnet pathtools sacremoses seqeval
# Installing collected packages: urllib3, requests, jmespath, smmap, botocore, s3transfer, pydantic, gitdb, filelock, commonmark, tokenizers, thinc, shortuuid, setproctitle, sentry-sdk, rich, pluggy, pathtools, iniconfig, huggingface-hub, GitPython, exceptiongroup, docker-pycreds, boto3, xxhash, wandb, transformers, traitlets, termcolor, tensorboardX, spacy, sentencepiece, sacremoses, responses, pytest, multiprocess, lmdb, jsonnet, h5py, fairscale, cached-path, base58, seqeval, datasets, allennlp, tner
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.8.0
#     Uninstalling filelock-3.8.0:
#       Successfully uninstalled filelock-3.8.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.1.0
#     Uninstalling termcolor-2.1.0:
#       Successfully uninstalled termcolor-2.1.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.2
#     Uninstalling spacy-3.4.2:
#       Successfully uninstalled spacy-3.4.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Attempting uninstall: lmdb
#     Found existing installation: lmdb 0.99
#     Uninstalling lmdb-0.99:
#       Successfully uninstalled lmdb-0.99
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.3.1 which is incompatible.
# Successfully installed GitPython-3.1.29 allennlp-2.10.1 base58-2.1.1 boto3-1.26.11 botocore-1.29.11 cached-path-1.1.6 commonmark-0.9.1 datasets-2.7.0 docker-pycreds-0.4.0 exceptiongroup-1.0.4 fairscale-0.4.6 filelock-3.7.1 gitdb-4.0.9 h5py-3.7.0 huggingface-hub-0.10.1 iniconfig-1.1.1 jmespath-1.0.1 jsonnet-0.19.1 lmdb-1.3.0 multiprocess-0.70.14 pathtools-0.1.2 pluggy-1.0.0 pydantic-1.8.2 pytest-7.2.0 requests-2.28.1 responses-0.18.0 rich-12.6.0 s3transfer-0.6.0 sacremoses-0.0.53 sentencepiece-0.1.97 sentry-sdk-1.11.0 seqeval-1.2.2 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 spacy-3.3.1 tensorboardX-2.5.1 termcolor-1.1.0 thinc-8.0.17 tner-0.2.0 tokenizers-0.12.1 traitlets-5.5.0 transformers-4.20.1 urllib3-1.26.12 wandb-0.12.21 xxhash-3.1.0
# tner                          0.2.0

# %%
import logging
from tner import GridSearcher, TransformersNER

logging.basicConfig(format='%(asctime)s %(levelname)-8s %(message)s', level=logging.INFO, datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Finetuning
# Let's finetune `albert-base-v1` on `wnut2017`!

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_tweebank',
   dataset="tner/tweebank_ner",  # either of `dataset` (huggingface dataset) or `local_dataset` (custom dataset) should be given
   model="roberta-large",  # language model to fine-tune
   epoch=10,  # the total epoch (`L` in the figure)
   epoch_partial=5,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=32,
   gradient_accumulation_steps=[2],
   crf=[True],
   lr=[1e-3, 1e-4],
   weight_decay=[None], 
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10])

# %%
searcher.train()
# Out:
# INFO:root:INITIALIZE GRID SEARCHER: 4 configs to try
# INFO:root:## 1st RUN: Configuration 0/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/tweebank_ner
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# Downloading builder script:   0%|          | 0.00/2.97k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/2.12k [00:00<?, ?B/s]
# Downloading and preparing dataset tweebank_ner/tweebank_ner to /root/.cache/huggingface/datasets/tner___tweebank_ner/tweebank_ner/1.0.0/1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/243k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/317k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/148k [00:00<?, ?B/s]
# Extracting data files #0:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #2:   0%|          | 0/1 [00:00<?, ?obj/s]
# Extracting data files #1:   0%|          | 0/1 [00:00<?, ?obj/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--tweebank_ner.1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812.tweebank_ner:generating examples from = /root/.cache/huggingface/datasets/downloads/0285d49e607834ff24ef0941f45ded26f90d8565d04e97e6786e102e3edc30f9
# Generating validation split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--tweebank_ner.1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812.tweebank_ner:generating examples from = /root/.cache/huggingface/datasets/downloads/67688699ff05bc940757d7c4dee5bc6e9701385931f42f6817cf813fcaf778e2
# Generating test split: 0 examples [00:00, ? examples/s]
# INFO:datasets_modules.datasets.tner--tweebank_ner.1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812.tweebank_ner:generating examples from = /root/.cache/huggingface/datasets/downloads/e2ea8b93def80d293ad509073b49ca65f984a5b572a99c9389406c9c351f8f5c
# Dataset tweebank_ner downloaded and prepared to /root/.cache/huggingface/datasets/tner___tweebank_ner/tweebank_ner/1.0.0/1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-MISC': 1, 'B-ORG': 2, 'B-PER': 3, 'I-LOC': 4, 'I-MISC': 5, 'I-ORG': 6, 'I-PER': 7, 'O': 8}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 1639
# INFO:root:preprocessed feature is saved at ./ckpt_bert_tweebank/model_ubskso/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 975.18, lr: 0.001
# INFO:root:[epoch 0/10] average loss: 959.42, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 282.26, lr: 0.0008888888888888888
# INFO:root:[epoch 1/10] average loss: 281.41, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 275.74, lr: 0.0007777777777777778
# INFO:root:[epoch 2/10] average loss: 277.37, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 275.6, lr: 0.0006666666666666666
# INFO:root:[epoch 3/10] average loss: 276.84, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 270.95, lr: 0.0005555555555555556
# INFO:root:[epoch 4/10] average loss: 275.26, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_ubskso/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_ubskso/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_tweebank/model_ubskso
# INFO:root:## 1st RUN: Configuration 1/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/tweebank_ner
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset tweebank_ner (/root/.cache/huggingface/datasets/tner___tweebank_ner/tweebank_ner/1.0.0/1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-MISC': 1, 'B-ORG': 2, 'B-PER': 3, 'I-LOC': 4, 'I-MISC': 5, 'I-ORG': 6, 'I-PER': 7, 'O': 8}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 1639
# INFO:root:preprocessed feature is saved at ./ckpt_bert_tweebank/model_udaxih/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 542.74, lr: 0.001
# INFO:root:[epoch 0/10] average loss: 535.64, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 290.42, lr: 0.0008888888888888888
# INFO:root:[epoch 1/10] average loss: 289.49, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 1241.89, lr: 0.0007777777777777778
# INFO:root:[epoch 2/10] average loss: 1225.98, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 284.51, lr: 0.0006666666666666666
# INFO:root:[epoch 3/10] average loss: 286.42, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 282.75, lr: 0.0005555555555555556
# INFO:root:[epoch 4/10] average loss: 286.77, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_tweebank/model_udaxih
# INFO:root:## 1st RUN: Configuration 2/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/tweebank_ner
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# WARNING:datasets.builder:Found cached dataset tweebank_ner (/root/.cache/huggingface/datasets/tner___tweebank_ner/tweebank_ner/1.0.0/1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-MISC': 1, 'B-ORG': 2, 'B-PER': 3, 'I-LOC': 4, 'I-MISC': 5, 'I-ORG': 6, 'I-PER': 7, 'O': 8}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 1639
# INFO:root:preprocessed feature is saved at ./ckpt_bert_tweebank/model_hexdvx/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 646.81, lr: 0.0001
# INFO:root:[epoch 0/10] average loss: 637.66, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 240.15, lr: 8.888888888888889e-05
# INFO:root:[epoch 1/10] average loss: 238.64, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 159.77, lr: 7.777777777777778e-05
# INFO:root:[epoch 2/10] average loss: 160.14, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 105.54, lr: 6.666666666666667e-05
# INFO:root:[epoch 3/10] average loss: 105.59, lr: 6.666666666666667e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 65.4, lr: 5.555555555555556e-05
# INFO:root:[epoch 4/10] average loss: 65.94, lr: 5.555555555555556e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_tweebank/model_hexdvx
# INFO:root:## 1st RUN: Configuration 3/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/tweebank_ner
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: roberta-large
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset tweebank_ner (/root/.cache/huggingface/datasets/tner___tweebank_ner/tweebank_ner/1.0.0/1a4677dc1bfe316a09cdbca887f9a7f1b1b01bc7dcd8c2cc234962a15af9f812)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `roberta-large`
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaForTokenClassification: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForTokenClassification were not initialized from the model checkpoint at roberta-large and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-LOC': 0, 'B-MISC': 1, 'B-ORG': 2, 'B-PER': 3, 'I-LOC': 4, 'I-MISC': 5, 'I-ORG': 6, 'I-PER': 7, 'O': 8}
# INFO:root:device   : cuda
# INFO:root:gpus     : 1
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 1639
# INFO:root:preprocessed feature is saved at ./ckpt_bert_tweebank/model_rcsnba/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 590.6, lr: 0.0001
# INFO:root:[epoch 0/10] average loss: 580.69, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_tweebank/model_rcsnba/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_rcsnba/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_rcsnba/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_rcsnba/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 164.23, lr: 8.888888888888889e-05
# INFO:root:[epoch 1/10] average loss: 163.22, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_rcsnba/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_rcsnba/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_rcsnba/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_rcsnba/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 108.32, lr: 7.777777777777778e-05
# INFO:root:[epoch 2/10] average loss: 108.82, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_tweebank/model_rcsnba/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_tweebank/model_rcsnba/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_tweebank/model_rcsnba/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_tweebank/model_rcsnba/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files

# %% [markdown]
# ### Evaluation
# Now the best model is stored at `ckpt_bert_wnut2017/best_model`, so let's load the model run evaluation on the test split.

# %% [markdown]
# First, we load the model and check the prediction.

# %%
model = TransformersNER("ckpt_bert_tweebank/best_model")
model.predict(["Jacob Collier is a Grammy awarded English artist from London"])

# %% [markdown]
# Then, the model instance has `evaluate` function where one can run evaluatino on the dataset easily.

# %%
metric = model.evaluate('tner/tweebank', dataset_split='test', batch_size=16)

# %%
metric

# %% [markdown]
# ## Finetuning on multiple datasets
# To finetune on multiple datasets, we need to give a list to the variable `dataset`.

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_multiple_dataset',
   dataset=["tner/wnut2017", "tner/fin"],  # either of `dataset` (huggingface dataset) or `local_dataset` (custom dataset) should be given
   model="distilbert-base-cased",  # language model to fine-tune
   epoch=10,  # the total epoch (`L` in the figure)
   epoch_partial=5,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=32,
   gradient_accumulation_steps=[2],
   crf=[True],
   lr=[1e-3, 1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()

# %%
model = TransformersNER("ckpt_bert_multiple_dataset/best_model")
metric_wnut = model.evaluate('tner/wnut2017', dataset_split='test', batch_size=16)
metric_fin = model.evaluate('tner/fin', dataset_split='test', batch_size=16)

# %%
metric_wnut

# %%
metric_fin

# %% [markdown]
# ## Finetuning on a custom dataset
# Finetuning on a [custom dataset](https://github.com/asahi417/tner/tree/master/examples/custom_dataset_sample).

# %%
# !mkdir ./custom_data
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/train.txt -O custom_data/train.txt
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/valid.txt -O custom_data/valid.txt
# !wget https://raw.githubusercontent.com/asahi417/tner/master/examples/local_dataset_sample/test.txt -O custom_data/test.txt

# %%
# !head -n 5 custom_data/train.txt

# %%
local_dataset = {"train": "custom_data/train.txt", "validation": "custom_data/valid.txt", "test": "custom_data/test.txt"}

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_custom_dataset',
   local_dataset=local_dataset,
   model="distilbert-base-cased",  # language model to fine-tune
   epoch=2,  # the total epoch (`L` in the figure)
   epoch_partial=1,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=4,
   gradient_accumulation_steps=[1],
   crf=[True],
   lr=[1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()

# %%
model = TransformersNER("ckpt_bert_custom_dataset/best_model")
metric = model.evaluate(local_dataset=local_dataset, dataset_split='test', batch_size=16)

# %%
metric
